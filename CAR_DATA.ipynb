# %% [markdown]
# # CAR DATA SET ANALYSIS

# %% [markdown]
# # import the libraries

# %%
import pandas as pd 
import sys

# %% [markdown]
# # load the data in csv format

# %%
car_df=pd.read_csv(r"C:\Users\ASUS\Desktop\codde\data file\Cars_Data.csv")
car_df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # To check null values in dataset

# %%
car_df.isnull().sum()

# %%
# there  are two null values we will use mean() to remove the null values
car_df.Cylinders.fillna(car_df.Cylinders.mean(),inplace =True)
car_df

# %% [markdown]
# # to get all the unique values in each column

# %%
car_df.nunique()

# %% [markdown]
# # to get types of data in one column

# %%
car_df.Type.unique()

# %%
car_df["Origin"].unique()

# %%
car_df.DriveTrain.unique()

# %% [markdown]
# # to check the occurence of every data in each cell

# %%
car_df.DriveTrain.value_counts()

# %%
car_df.EngineSize.value_counts()

# %%
car_df.Make.value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Kia              11
# Lexus            11
# Mazda            11
# Pontiac          11
# Mercury           9
# Lincoln           9
# Buick             9
# Cadillac          8
# Suzuki            8
# Saturn            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Jeep              3
# Land Rover        3
# Oldsmobile        3
# Scion             2
# MINI              2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# # show the data where origin is Asia and type should be Sedan

# %%
car_df[(car_df["Origin"]=="Asia") & (car_df["Type"]=="Sedan")]

# %% [markdown]
# # show the data of Toyota with 190 horsepower

# %%
car_df[(car_df.Make=="Toyota") & (car_df.Horsepower==190)]

# %% [markdown]
# # show the records where DriveTrain is  front and Rare

# %%
car_df[car_df["DriveTrain"].isin(["Front","Rear"])].head(50)
# Out:
#          Make                           Model    Type  Origin DriveTrain  \
# 1       Acura                  RSX Type S 2dr   Sedan    Asia      Front
# 2       Acura                         TSX 4dr   Sedan    Asia      Front
# 3       Acura                          TL 4dr   Sedan    Asia      Front
# 4       Acura                      3.5 RL 4dr   Sedan    Asia      Front
# 5       Acura         3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6       Acura          NSX coupe 2dr manual S  Sports    Asia       Rear
# 7        Audi                     A4 1.8T 4dr   Sedan  Europe      Front
# 8        Audi          A41.8T convertible 2dr   Sedan  Europe      Front
# 9        Audi                      A4 3.0 4dr   Sedan  Europe      Front
# 12       Audi                      A6 3.0 4dr   Sedan  Europe      Front
# 14       Audi          A4 3.0 convertible 2dr   Sedan  Europe      Front
# 20       Audi                        RS 6 4dr  Sports  Europe      Front
# ...

# %% [markdown]
# # show the records of Pontiac ,volvo and BMW

# %%
car_df[car_df["Make"].isin(("Pontiac","Volvo","BMW"))].head(200)
# Out:
#         Make                    Model    Type  Origin DriveTrain      MSRP  \
# 26       BMW                  X3 3.0i     SUV  Europe        All  $37,000
# 27       BMW                  X5 4.4i     SUV  Europe        All  $52,195
# 28       BMW                 325i 4dr   Sedan  Europe       Rear  $28,495
# 29       BMW                325Ci 2dr   Sedan  Europe       Rear  $30,795
# 30       BMW    325Ci convertible 2dr   Sedan  Europe       Rear  $37,995
# 31       BMW                325xi 4dr   Sedan  Europe        All  $30,245
# 32       BMW                 330i 4dr   Sedan  Europe       Rear  $35,495
# 33       BMW                330Ci 2dr   Sedan  Europe       Rear  $36,995
# 34       BMW                330xi 4dr   Sedan  Europe        All  $37,245
# 35       BMW                 525i 4dr   Sedan  Europe       Rear  $39,995
# 36       BMW    330Ci convertible 2dr   Sedan  Europe       Rear  $44,295
# 37       BMW                 530i 4dr   Sedan  Europe       Rear  $44,995
# ...

# %% [markdown]
# # delete the record where MPG_city is greater than 20

# %%
car_df[~(car_df["MPG_City"]>20)]
# Out:
#       Make                    Model    Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX     SUV    Asia        All  $36,945
# 3    Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6    Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# ..     ...                      ...     ...     ...        ...       ...
# 421  Volvo              S80 2.9 4dr   Sedan  Europe      Front  $37,730
# 422  Volvo             S80 2.5T 4dr   Sedan  Europe        All  $37,885
# 424  Volvo  C70 HPT convertible 2dr   Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr   Sedan  Europe      Front  $45,210
# 427  Volvo                     XC70   Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # calculate mean of Horsepower

# %%
car_df["Horsepower"].mean()
# Out:
# 215.8855140186916

# %% [markdown]
# # calculate the median of Wheelbase

# %%
car_df["Wheelbase"].median()
# Out:
# 107.0
